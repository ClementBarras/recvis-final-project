# %%
from of_utils import make_score_list

# %%
root_folder = "../datasets/tvl1_flow/"
result_folder = "../datasets/tvl1_flow/average_flow/"
make_score_list(root_folder, result_folder)
# Out:
# subfolder = ../datasets/tvl1_flow/u/v_CricketShot_g25_c07 (13320/13320)
# skipping

# %%
import os

# %%
dir_list = os.scandir(result_folder)

for f in dir_list:
    if f.name[2:18] == "HandstandPushups":
        print(f.name.split("HandstandPushups"))
        pref, suf = f.name.split("HandstandPushups")[0], f.name.split("HandstandPushups")[1]
        new_name = pref + "HandStandPushups" + suf
        new_name = os.path.join(result_folder, new_name)
        #print(f.path, new_name)
        os.rename(f, new_name)
# Out:
# ['v_', '_g09_c04']
# ['v_', '_g13_c07']
# ['v_', '_g16_c01']
# ['v_', '_g03_c01']
# ['v_', '_g08_c04']
# ['v_', '_g16_c04']
# ['v_', '_g03_c03']
# ['v_', '_g23_c03']
# ['v_', '_g12_c03']
# ['v_', '_g16_c05']
# ['v_', '_g04_c03']
# ['v_', '_g15_c04']
# ['v_', '_g24_c02']
# ['v_', '_g23_c01']
# ['v_', '_g15_c06']
# ['v_', '_g12_c07']
# ['v_', '_g14_c03']
# ['v_', '_g13_c01']
# ['v_', '_g02_c02']
# ['v_', '_g03_c04']
# ['v_', '_g20_c04']
# ['v_', '_g19_c02']
# ['v_', '_g01_c04']
# ['v_', '_g06_c02']
# ['v_', '_g18_c07']
# ['v_', '_g10_c04']
# ['v_', '_g24_c04']
# ['v_', '_g15_c02']
# ['v_', '_g06_c04']
# ['v_', '_g20_c07']
# ['v_', '_g07_c01']
# ['v_', '_g21_c01']
# ['v_', '_g01_c01']
# ['v_', '_g12_c02']
# ['v_', '_g11_c04']
# ['v_', '_g25_c03']
# ['v_', '_g07_c02']
# ['v_', '_g01_c02']
# ['v_', '_g20_c01']
# ['v_', '_g18_c04']
# ['v_', '_g13_c04']
# ['v_', '_g10_c03']
# ['v_', '_g13_c06']
# ['v_', '_g13_c03']
# ['v_', '_g08_c02']
# ['v_', '_g18_c02']
# ['v_', '_g22_c02']
# ...
