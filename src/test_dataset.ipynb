# %%
from dataset import ProxyTaskDataset, SupervisedDataset
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torch
import os
from time import time
print(os.getcwd())
# Out:
# /workspace/recvis-final-project/src

# %%
train_set = ProxyTaskDataset(sampling='constrained_consecutive', n_samples=10)
#train_set = SupervisedDataset(train=False)
loader = DataLoader(train_set, batch_size=100, shuffle=True, num_workers=0)
#print(train_set.video_list)

# %%
start = time()
a = next(iter(loader))
end = time()
print(end - start)
#print(a.shape)
#for i in a[0][0]:
 #   fig, ax = plt.subplots(1,6, figsize=(14,14))
   # i = i.permute((1,2,3,0))
   # for j, im in enumerate(i):
   #     im = torch.squeeze(im)
     #   ax[j].imshow(im.numpy())
# Out:
# 96.8126871585846

# %%
from i3d import I3D
from torchsummary import summary
import torch
model = I3D(num_classes=400)
model.cuda()
model.load_state_dict(torch.load('../models/model_rgb.pth'))
summary(model, (3,10,224,224))  # Tensor dimensions = (batch_size, rgb or flow channels, nb_frames, height, width)
#zeros = torch.zeros([2,3,16,224,224]).cuda()
#out = model(zeros)
#print(out)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-f9458c9a76ac> in <module>
#       1 from i3d import I3D
# ----> 2 from torchsummary import summary
#       3 import torch
#       4 model = I3D(num_classes=400)
#       5 model.cuda()
#
# ModuleNotFoundError: No module named 'torchsummary'

# %%
import numpy as np
model_parameters = filter(lambda p: p.requires_grad, model.parameters())
params = sum([np.prod(p.size()) for p in model_parameters])
model.state_dict
# Out:
# <bound method Module.state_dict of I3D(
#   (conv3d_1a_7x7): Unit3Dpy(
#     (pad): ConstantPad3d(padding=(2, 3, 2, 3, 2, 3), value=0)
#     (conv3d): Conv3d(3, 64, kernel_size=(7, 7, 7), stride=(2, 2, 2), bias=False)
#     (batch3d): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxPool3d_2a_3x3): MaxPool3dTFPadding(
#     (pad): ConstantPad3d(padding=(0, 1, 0, 1, 0, 0), value=0)
#     (pool): MaxPool3d(kernel_size=(1, 3, 3), stride=(1, 2, 2), padding=0, dilation=1, ceil_mode=True)
#   )
#   (conv3d_2b_1x1): Unit3Dpy(
#     (conv3d): Conv3d(64, 64, kernel_size=(1, 1, 1), stride=(1, 1, 1), bias=False)
#     (batch3d): BatchNorm3d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3d_2c_3x3): Unit3Dpy(
#     (conv3d): Conv3d(64, 192, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1), bias=False)
#     (batch3d): BatchNorm3d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
# ...

# %%
run self_supervised_main.py --n_samples=10 --batch-size=64 --lr=0.001 --log-interval=1
# Out:
# Using GPU
# /workspace/recvis-final-project/src/odd_one_out.py:24: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
#   output = F.softmax(self.fc2(x))
# Train Epoch: 1 [0/9060 (0%)]	Loss: 1.792662
# Train Epoch: 1 [64/9060 (1%)]	Loss: 1.791584
# Train Epoch: 1 [128/9060 (1%)]	Loss: 1.791484
# Train Epoch: 1 [192/9060 (2%)]	Loss: 1.793214
# Train Epoch: 1 [256/9060 (3%)]	Loss: 1.791607
# Train Epoch: 1 [320/9060 (4%)]	Loss: 1.792535
# Train Epoch: 1 [384/9060 (4%)]	Loss: 1.792770
# Train Epoch: 1 [448/9060 (5%)]	Loss: 1.791625
# Train Epoch: 1 [512/9060 (6%)]	Loss: 1.792941
# Train Epoch: 1 [576/9060 (6%)]	Loss: 1.792889
# Train Epoch: 1 [640/9060 (7%)]	Loss: 1.792939
# Train Epoch: 1 [704/9060 (8%)]	Loss: 1.790715
# Train Epoch: 1 [768/9060 (8%)]	Loss: 1.789815
# Train Epoch: 1 [832/9060 (9%)]	Loss: 1.789587
# Train Epoch: 1 [896/9060 (10%)]	Loss: 1.793673
# Train Epoch: 1 [960/9060 (11%)]	Loss: 1.791945
# ...

# %%
run evaluateO3N.py --model='experiment/model_2.pth'
# Out:
# Using GPU
# GPU usage:
#   memory.used memory.free
# 0   11374 MiB     832 MiB
# 1      11 MiB   12195 MiB
# Using GPU1 with 12195.0 free MiB
# 1
# 2
# 3
